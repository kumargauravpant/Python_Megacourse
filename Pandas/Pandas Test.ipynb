# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Pandas Test.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas

# %%
dir(pandas)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
# ...

# %%
df1 = pandas.read_json("supermarkets.json")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)

# %%
df2
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3 = pandas.read_csv("supermarkets.csv")

# %%
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pandas.read_csv("supermarkets-semi-colons.txt", separator=";")
df4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-764904f3c9f0> in <module>
# ----> 1 df4 = pandas.read_csv("supermarkets-semi-colons.txt", separator=";")
#       2 df4
#
# TypeError: parser_f() got an unexpected keyword argument 'separator'

# %%
pandas.read_csv?

# %%
df4 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4.Address[1]
# Out:
# '735 Dolores St'

# %%
df4.1
# Out:
#   File "<ipython-input-28-476d1937a6a6>", line 1
#     df4.1
#        ^
# SyntaxError: invalid syntax

# %%
df5 = df4.set_index("ID")

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.loc[1]
# Out:
# Address       3666 21st St
# City         San Francisco
# State             CA 94114
# Country                USA
# Name               Madeira
# Employees                8
# Name: 1, dtype: object

# %%
df5.iloc[1:3,1:3]
# Out:
#              City             State
# ID
# 2   San Francisco          CA 94119
# 3   San Francisco  California 94114

# %%
df5.ix[3,4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-ac03d8bc5367> in <module>
# ----> 1 df5.ix[3,4]
#
# c:\users\kumar\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
df5["Country"] = "UK"

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114      UK       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      UK   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      UK   Super River
# 4      3995 23rd St  San Francisco          CA 94114      UK    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      UK       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      UK    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5["Country"][1] = "USA"
# Out:
# <ipython-input-56-ad0df7099aa0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["Country"][1] = "USA"

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      UK   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      UK   Super River
# 4      3995 23rd St  San Francisco          CA 94114      UK    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      UK       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      UK    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5.T
# Out:
# ID                     1               2                 3              4  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA              UK                UK             UK
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
#
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State           California         CA 94114
# Country                 UK               UK
# Name               Sanchez       Richvalley
# Employees               12               20

# %%
df5
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      UK   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      UK   Super River
# 4      3995 23rd St  San Francisco          CA 94114      UK    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      UK       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      UK    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode("Sai Gardens Apartment, yemalur,Bangalore, 560037")
# Out:
# Location(Project Sai Gardens, (12.946250000000077, 77.67553000000004, 0.0))

# %%
n = nom.geocode("Fore Street, Exeter, EX12RS")

# %%
n.latitude
# Out:
# 50.721349339198184

# %%
n.longitude
# Out:
# -3.5051768295839243

# %%
df4["Address"] = df4["Address"] + ", " + df4["City"]+ ", " + df4["State"]+ ", " + df4["Country"]

# %%
df4
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country          Name  Employees  \
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20
#
#                                          Coordinates
# ...

# %%
df4["Coordinates"]=df4["Address"].apply(nom.geocode)

# %%
df4.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.7564496899993, -122.42936434915458, 0.0))

# %%
df4.Coordinates[0].latitude
# Out:
# 37.7564496899993

# %%
df4["Latitude"] = df4["Coordinates"].apply(lambda x:x.latitude)
df4["Longitude"] = df4["Coordinates"].apply(lambda x:x.longitude)

# %%
df4
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country          Name  Employees  \
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
